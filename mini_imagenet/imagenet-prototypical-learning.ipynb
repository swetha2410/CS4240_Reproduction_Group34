# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/mini-imagenet/valid.pkl
# /kaggle/input/mini-imagenet/train.pkl
# /kaggle/input/mini-imagenet/test.pkl

# %%
#clone the git repo
import git
git.Repo.clone_from('https://github.com/yashmundhra/prototypical-networks-ymundhra.git', '/kaggle/working/prototypical-networks')
# Out:
# <git.repo.base.Repo '/kaggle/working/prototypical-networks/.git'>

# %%
ls /kaggle/working/prototypical-networks/
# Out:
# LICENSE      README.md   requirements.txt  setup.py
# MANIFEST.in  protonets/  scripts/

# %%
cd ..
# Out:
# /kaggle

# %%
# !cp -r input /kaggle/working/prototypical-networks/scripts/datasets/

# %%
# !mv /kaggle/working/prototypical-networks/scripts/datasets/mini-imagenet /kaggle/working/prototypical-networks/scripts/datasets/mini_imagenet

# %% [markdown]
# # TODO: Move to protoypical-networks directory

# %%
# !pip3 install -r working/prototypical-networks/requirements.txt
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 46.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 49.9 MB/s eta 0:00:00
# ...
# done
# done
# done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 821.2 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.9/37.9 MB 39.1 MB/s eta 0:00:00
# done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 4.9 MB/s eta 0:00:00
# ...
# done
#   Created wheel for gdown: filename=gdown-3.13.1-py3-none-any.whl size=9889 sha256=f4eb9ec6e799df754cff399ed810764127f7e56b45706b68053bc5fb22526f5e
# ...

# %%
# !pip3 install -e working/prototypical-networks/.
# Out:
# Obtaining file:///kaggle/working/prototypical-networks
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for protonets
# ...

# %%
# !python3 working/prototypical-networks/scripts/training.py -m vanilla -d mini_imagenet
# Out:
# Reading images from /kaggle/working/prototypical-networks/scripts/datasets/mini_
# Reading images from /kaggle/working/prototypical-networks/scripts/datasets/mini_
# ==> Epoch 1
# > Training
# 100%|█████████████████████████████████████████| 100/100 [00:22<00:00,  4.36it/s]
# Loss: 43.9344 / Acc: 7.72%
# > Validation
# 100%|█████████████████████████████████████████| 100/100 [00:03<00:00, 26.43it/s]
# Loss: 2.4981 / Acc: 27.47%
# => This is the best model so far! Saving...
# ==> Epoch 2
# > Training
# 100%|█████████████████████████████████████████| 100/100 [00:22<00:00,  4.48it/s]
# Loss: 3.8276 / Acc: 7.52%
# > Validation
# 100%|█████████████████████████████████████████| 100/100 [00:03<00:00, 26.53it/s]
# Loss: 1.7475 / Acc: 28.80%
# => This is the best model so far! Saving...
# ==> Epoch 3
# > Training
# 100%|█████████████████████████████████████████| 100/100 [00:22<00:00,  4.52it/s]
# Loss: 3.4274 / Acc: 8.54%
# > Validation
# ...

# %%
# !python3 working/prototypical-networks/scripts/evaluation.py
# Out:
# Reading images from /kaggle/working/prototypical-networks/scripts/datasets/mini_
# > Testing
# 100%|█████████████████████████████████████████| 600/600 [00:22<00:00, 26.27it/s]
# Loss: 1.2823 / Acc: 47.37 +/- 0.80%
# > Testing
# 100%|█████████████████████████████████████████| 600/600 [00:22<00:00, 26.23it/s]
# Loss: 1.2828 / Acc: 47.62 +/- 0.78%
# > Testing
# 100%|█████████████████████████████████████████| 600/600 [00:22<00:00, 26.24it/s]
# Loss: 1.2975 / Acc: 46.48 +/- 0.82%
# > Testing
# 100%|█████████████████████████████████████████| 600/600 [00:22<00:00, 26.10it/s]
# Loss: 1.2980 / Acc: 46.83 +/- 0.79%
# > Testing
# 100%|█████████████████████████████████████████| 600/600 [00:22<00:00, 26.27it/s]
# Loss: 1.2947 / Acc: 47.23 +/- 0.81%
# > Testing
# 100%|█████████████████████████████████████████| 600/600 [00:22<00:00, 26.27it/s]
# Loss: 1.2897 / Acc: 47.05 +/- 0.83%
# > Testing
# 100%|█████████████████████████████████████████| 600/600 [00:22<00:00, 26.25it/s]
# ...
